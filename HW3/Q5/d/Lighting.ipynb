# %% [markdown]
# # Import Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Create Image

# %%
original_image = np.zeros((400, 400, 3), dtype=np.uint8)
original_image[:200, :200, 0] += 64
original_image[:200, 200:, 1] += 64
original_image[200:, :200, 2] += 64
original_image[200:, 200:] += 64

# %% [markdown]
# # Show the image in RGB

# %%
original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)
cv2.imshow('Original Image', original_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.title("first method")
plt.imshow(original_image)
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # First Method

# %%
first_image = original_image.copy()
first_image += 64

# %% [markdown]
# # Second Method

# %%
second_image = original_image.copy()
second_image = cv2.cvtColor(second_image, cv2.COLOR_RGB2HLS)
second_image[:, :, 1] += 64
second_image = cv2.cvtColor(second_image, cv2.COLOR_HLS2RGB)

# %% [markdown]
# # Display both first and second images

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.title("first method")
plt.imshow(first_image)
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title("second method")
plt.imshow(second_image)
plt.axis('off')

plt.tight_layout()
plt.show()
